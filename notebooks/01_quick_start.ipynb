# %% [markdown]
# # 01 Quick Start

# %%
from legopolitics import AnalysisConfig, LegoPoliticsAnalyzer
config = AnalysisConfig.from_yaml("../configs/minimal.yaml")
